# %%
# !pip install pandas nltk tqdm spacy
# Out:
# Requirement already satisfied: pandas in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (2.0.2)
# Requirement already satisfied: nltk in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: tqdm in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (4.65.0)
# Collecting spacy
#   Downloading spacy-3.7.2-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: click in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: colorama in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy)
#   Downloading thinc-8.2.2-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.9.0)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy) (23.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#      ----------------------- -------------- 112.6/181.6 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 181.6/181.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy)
#   Downloading blis-0.7.11-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy) (2.1.3)
# Downloading spacy-3.7.2-cp311-cp311-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.1 MB 1.6 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/12.1 MB 177.2 kB/s eta 0:01:08
#     --------------------------------------- 0.2/12.1 MB 255.6 kB/s eta 0:00:47
#     --------------------------------------- 0.2/12.1 MB 320.0 kB/s eta 0:00:37
#    - -------------------------------------- 0.4/12.1 MB 487.6 kB/s eta 0:00:24
#    -- ------------------------------------- 0.7/12.1 MB 825.0 kB/s eta 0:00:14
#    -- ------------------------------------- 0.9/12.1 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.1/12.1 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/12.1 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.1 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.7/12.1 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/12.1 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 2.0/12.1 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.1 MB 1.8 MB/s eta 0:00:06
#    ------- -------------------------------- 2.2/12.1 MB 1.8 MB/s eta 0:00:06
#    ------- -------------------------------- 2.3/12.1 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.5/12.1 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 2.8/12.1 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.1 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/12.1 MB 2.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.5/12.1 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/12.1 MB 2.4 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/12.1 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.1/12.1 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 4.4/12.1 MB 2.6 MB/s eta 0:00:03
#    --------------- ------------------------ 4.6/12.1 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 4.8/12.1 MB 2.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.0/12.1 MB 2.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.2/12.1 MB 2.8 MB/s eta 0:00:03
#    ------------------ --------------------- 5.4/12.1 MB 2.9 MB/s eta 0:00:03
#    ------------------ --------------------- 5.6/12.1 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 5.8/12.1 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.1 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.1 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.1 MB 2.9 MB/s eta 0:00:03
#    --------------------- ------------------ 6.6/12.1 MB 3.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.8/12.1 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.0/12.1 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.2/12.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.4/12.1 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 7.8/12.1 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.9/12.1 MB 3.2 MB/s eta 0:00:02
#    --------------------------- ------------ 8.2/12.1 MB 3.3 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.1 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.6/12.1 MB 3.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.8/12.1 MB 3.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.0/12.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------------ --------- 9.2/12.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.4/12.1 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.1 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.0/12.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.3/12.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.1 MB 4.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.8/12.1 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.1/12.1 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.1 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.5/12.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 4.6 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl (39 kB)
# Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.3 kB ? eta -:--:--
#    ---------------------------------------- 122.3/122.3 kB 7.5 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl (479 kB)
#    ---------------------------------------- 0.0/479.7 kB ? eta -:--:--
#    ----------------------------- --------- 358.4/479.7 kB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 479.7/479.7 kB 7.5 MB/s eta 0:00:00
# Downloading thinc-8.2.2-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB 8.6 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.5 MB 9.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.5 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.5 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.9 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB 2.5 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/6.6 MB 7.4 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/6.6 MB 7.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/6.6 MB 6.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.2/6.6 MB 6.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.6 MB 6.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.8/6.6 MB 6.5 MB/s eta 0:00:01
#    ------------- -------------------------- 2.2/6.6 MB 6.6 MB/s eta 0:00:01
#    --------------- ------------------------ 2.5/6.6 MB 7.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.8/6.6 MB 6.9 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.6 MB 6.5 MB/s eta 0:00:01
#    ------------------- -------------------- 3.3/6.6 MB 6.6 MB/s eta 0:00:01
#    --------------------- ------------------ 3.6/6.6 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.8/6.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------ --------------- 4.1/6.6 MB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.3/6.6 MB 6.3 MB/s eta 0:00:01
#    --------------------------- ------------ 4.6/6.6 MB 6.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.9/6.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.5/6.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.7/6.6 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.7/6.6 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.7/6.6 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.9/6.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 6.1/6.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 6.1/6.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 6.3/6.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  6.5/6.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 5.1 MB/s eta 0:00:00
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 45.0/45.0 kB ? eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, langcodes, cloudpathlib, catalogue, blis, srsly, preshed, confection, weasel, thinc, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 wasabi-1.1.2 weasel-0.3.4
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from tqdm import tqdm
import spacy

# %%
# NLTK RESOURCES

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\habee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\habee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\habee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
df = pd.read_csv('DATA_SET/final_test.csv')
df.head(-1)
# Out:
#                                                     text  label
# 0      The Face on Mars is nothing but a natural occu...      0
# 1      Students have a higher chance of catching a vi...      0
# 2      Driverless cars have good and bad things that ...      0
# 3      Some people might think that traveling in a gr...      1
# 4      How many of us students want to be forced to d...      0
# ...                                                  ...    ...
# 86581  Dear (Senator of Florida),\n\nIn my opinion I ...      0
# 86582  Dear Principal: I think we should have cell ph...      0
# 86583  Dear Teacher_NAME\n\nI think that if you try t...      0
# 86584  Venus is sometimes called the "meaning Star." ...      0
# 86585  The Seagoing Cowboy Bros\n\nDo you like going ...      0
#
# [86586 rows x 2 columns]

# %%
def calculate_features(text):
    # Character count
    char_count = len(text)

    # Punctuation count
    punctuation_count = sum(1 for char in text if char in string.punctuation)

    # Title word count
#     title_word_count = sum(1 for word in word_tokenize(text) if word.istitle())

    # Uppercase count
    upper_case_count = sum(1 for char in text if char.isupper())

    # Part-of-speech tagging
#     pos_tags = pos_tag(word_tokenize(text))
    noun_count = sum(1 for tag in pos_tags if tag[1] in ['NN', 'NNS', 'NNP', 'NNPS'])
    adv_count = sum(1 for tag in pos_tags if tag[1] in ['RB', 'RBR', 'RBS'])
    verb_count = sum(1 for tag in pos_tags if tag[1] in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'])
    adj_count = sum(1 for tag in pos_tags if tag[1] in ['JJ', 'JJR', 'JJS'])
    pro_count = sum(1 for tag in pos_tags if tag[1] in ['PRP', 'PRP$', 'WP', 'WP$'])

    return char_count, punctuation_count, title_word_count, upper_case_count, noun_count, adv_count, verb_count, adj_count, pro_count


def punctuation_count(text):
    return sum(1 for char in text if char in string.punctuation)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 2.6 MB/s eta 0:00:05
#       --------------------------------------- 0.2/12.8 MB 2.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/12.8 MB 2.6 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/12.8 MB 2.5 MB/s eta 0:00:05
#      - -------------------------------------- 0.6/12.8 MB 2.5 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/12.8 MB 2.8 MB/s eta 0:00:05
#      -- ------------------------------------- 1.0/12.8 MB 3.0 MB/s eta 0:00:04
#      --- ------------------------------------ 1.1/12.8 MB 3.1 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/12.8 MB 3.4 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.7/12.8 MB 3.5 MB/s eta 0:00:04
#      ------ --------------------------------- 2.0/12.8 MB 3.8 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.8 MB 4.0 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.1 MB/s eta 0:00:03
#      ------- -------------------------------- 2.6/12.8 MB 4.0 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.9/12.8 MB 3.3 MB/s eta 0:00:04
#      --------- ------------------------------ 3.2/12.8 MB 3.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.3/12.8 MB 3.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.5/12.8 MB 3.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.6/12.8 MB 3.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.6/12.8 MB 3.4 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.3 MB/s eta 0:00:03
#      ------------ --------------------------- 4.0/12.8 MB 3.3 MB/s eta 0:00:03
#      ------------- -------------------------- 4.4/12.8 MB 3.5 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 3.6 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 3.7 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.3/12.8 MB 3.8 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 3.9 MB/s eta 0:00:02
#      ------------------ --------------------- 5.9/12.8 MB 4.0 MB/s eta 0:00:02
#      ------------------- -------------------- 6.2/12.8 MB 4.0 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.8 MB 4.1 MB/s eta 0:00:02
#      -------------------- ------------------- 6.7/12.8 MB 4.1 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 4.2 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 4.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.5/12.8 MB 4.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.7/12.8 MB 4.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------------- -------------- 8.3/12.8 MB 4.1 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 4.2 MB/s eta 0:00:02
#      --------------------------- ------------ 8.8/12.8 MB 4.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 4.3 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.3/12.8 MB 4.3 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 4.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 4.4 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 4.4 MB/s eta 0:00:01
#      --------------------------------- ------ 10.6/12.8 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.9/12.8 MB 4.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.8 MB 4.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 4.9 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\habee\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# df['char_count'] = df['text'].apply(len)
df['word_count'] = df['text'].apply(lambda x: len(word_tokenize(x)))

df['word_count'] = df['text'].apply(punctuation_count)

# df['word_count'] = tqdm(df['word_count'])

# # word_count = len(word_tokenize(text))
# df['word_count'] = df['text'].apply(len)

# nlp = spacy.load("en_core_web_sm")

# # Assuming 'text' is the column in your DataFrame containing the text data
# df['word_count'] = df['text'].apply(lambda x: len([token.text for token in nlp(x)]))


# df[['char_count', 'punctuation_count', 'title_word_count','upper_case_count', 'noun_count', 'adv_count', 'verb_count', 'adj_count', 'pro_count']] = df['text'].apply(lambda x: pd.Series(calculate_features(x)))

# %%
df.head(-1)
# Out:
#                                                     text  label  char_count  \
# 0      The Face on Mars is nothing but a natural occu...      0        1377
# 1      Students have a higher chance of catching a vi...      0        3521
# 2      Driverless cars have good and bad things that ...      0        1656
# 3      Some people might think that traveling in a gr...      1         337
# 4      How many of us students want to be forced to d...      0        3499
# ...                                                  ...    ...         ...
# 86581  Dear (Senator of Florida),\n\nIn my opinion I ...      0        2589
# 86582  Dear Principal: I think we should have cell ph...      0        1755
# 86583  Dear Teacher_NAME\n\nI think that if you try t...      0        1550
# 86584  Venus is sometimes called the "meaning Star." ...      0         909
# 86585  The Seagoing Cowboy Bros\n\nDo you like going ...      0        2064
#
#        word_count
# 0             292
# 1             666
# 2             329
# 3              73
# 4             673
# ...           ...
# 86581         509
# 86582         369
# 86583         292
# 86584         188
# 86585         426
#
# [86586 rows x 4 columns]

# %%
a = "Hey whats up, how much you want me to pay for this job?"
b = len(word_tokenize(df['text'][0]))
print(b)
# Out:
# 292

# %%
def wc(column):
    words = word_tokenize(column)
    return len(words)

df['wc'] = df.apply(lambda x: wc(x['text']), axis=1)

# %%
df['punctuation_count'] = df['text'].apply(punctuation_count)

# %%
df['word_density'] = df['word_count'] / df['char_count']
df.head(10)
# Out:
#                                                 text  label  char_count  \
# 0  The Face on Mars is nothing but a natural occu...      0        1377
# 1  Students have a higher chance of catching a vi...      0        3521
# 2  Driverless cars have good and bad things that ...      0        1656
# 3  Some people might think that traveling in a gr...      1         337
# 4  How many of us students want to be forced to d...      0        3499
# 5  In the past few years, cellphones have become ...      0        1640
# 6  Cell phones have become an essential tool for ...      1        2960
# 7  Hey there!  So, you know, making decisions in ...      1        1787
# 8  In my op pinon school is good how it is now. H...      0        2562
# 9  Researching the pros and cons of accelerated h...      1        1371
#
#    word_count   wc  punctuation_count  word_density
# 0         292  292                 52      0.212055
# 1         666  666                 62      0.189151
# 2         329  329                 24      0.198671
# 3          73   73                  6      0.216617
# 4         673  673                 62      0.192341
# 5         327  327                 44      0.199390
# 6         570  570                 72      0.192568
# 7         423  423                 86      0.236710
# 8         530  530                 43      0.206870
# 9         224  224                 22      0.163384

# %%
# Basic NLP Features

df['char_count'] = df['text'].apply(len) # char count

df['word_count'] = df['text'].apply(lambda x: len(word_tokenize(x))) # word count

df['word_density'] = df['word_count'] / df['char_count'] # word density

# punctuation count
def punctuation_count(text):
    return sum(1 for char in text if char in string.punctuation)

df['punctuation_count'] = df['text'].apply(punctuation_count)

# Upper case count
def upper_case_count(text):
    return sum(1 for char in text if char.isupper())

df['upper_case_count'] = df['text'].apply(upper_case_count)

# parts of speech
def parts_of_speech(text):
    
    pos_tags = pos_tag(word_tokenize(text))
    
    noun_count = sum(1 for tag in pos_tags if tag[1] in ['NN', 'NNS', 'NNP', 'NNPS'])
    adv_count = sum(1 for tag in pos_tags if tag[1] in ['RB', 'RBR', 'RBS'])
    verb_count = sum(1 for tag in pos_tags if tag[1] in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'])
    adj_count = sum(1 for tag in pos_tags if tag[1] in ['JJ', 'JJR', 'JJS'])
    pro_count = sum(1 for tag in pos_tags if tag[1] in ['PRP', 'PRP$', 'WP', 'WP$'])
    
    return noun_count, adv_count, verb_count, adj_count, pro_count

df[['noun_count','adv_count','verb_count','adj_count','pro_count']] = df['text'].apply(lambda x: parts_of_speech(x))
